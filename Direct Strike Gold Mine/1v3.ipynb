# %%
import time
import threading
import pandas as pd
import os

# -----------------------------
# INITIAL GAME STATE
# -----------------------------
goldMine = 1                      # Start with 1 goldmine
initial_gold = 280.0
first_mine_cost = 150
gold = initial_gold - first_mine_cost  # Subtract first goldmine cost
multiplier = 5 + (goldMine / 2)
start_time = time.time()
running = True
lock = threading.Lock()

# -----------------------------
# DATA STORAGE
# -----------------------------
gold_history = pd.DataFrame(columns=["seconds", "gold", "goldMine"])
max_duration = 2100  # 35 minutes

# -----------------------------
# GOLD ACCUMULATION FUNCTION
# -----------------------------
def gold_function():
    global gold, multiplier, gold_history, running
    last_update_time = time.time()

    while running:
        time.sleep(1)
        with lock:
            current_time = time.time()
            elapsed_time = current_time - start_time
            handicap=0
            if elapsed_time >= max_duration:
                print("\n⏰ 35 minutes have passed. Ending game.")
                running = False
                break

            # Handicap: +0.4 before 688s, -0.2 after
            if elapsed_time < 688 and elapsed_time> 50:
                handicap = 0.4
            elif elapsed_time >= 688:
                handicap = 0.2

            multiplier = 5 + (goldMine / 2) + handicap

            delta_time = current_time - last_update_time
            last_update_time = current_time

            gold += delta_time * multiplier
            seconds_passed = int(elapsed_time)

            # Log values
            gold_history.loc[len(gold_history)] = [seconds_passed, int(gold), goldMine]

            # Display output
            print("\n--- Game Status ---")
            print(f"Time: {seconds_passed} sec")
            print(f"Gold: {int(gold)}")
            print(f"Multiplier: {multiplier:.2f} (Handicap: {handicap:+.1f})")
            print(f"Goldmines: {goldMine}")

# -----------------------------
# USER INPUT FUNCTION
# -----------------------------
def get_user_input():
    global gold, goldMine, running
    last_mine_time = start_time  # Cooldown timer starts at game start
    cooldown = 90

    while running:
        user_input = input("\nEnter 'mine' to build a Goldmine (90 sec cooldown), or 'quit' to exit: ").strip().lower()

        if user_input == "mine":
            current_time = time.time()
            with lock:
                if current_time - last_mine_time >= cooldown:
                    cost = 150 + goldMine * 50
                    if gold >= cost:
                        goldMine += 1
                        gold -= cost
                        last_mine_time = current_time
                        print(f"✅ Built Goldmine #{goldMine}! (-{cost} gold)")
                    else:
                        print(f"❌ Not enough gold! You need {cost}, but have {int(gold)}.")
                else:
                    remaining = int(cooldown - (current_time - last_mine_time))
                    print(f"⏳ Goldmine is on cooldown. Wait {remaining} more seconds.")
        elif user_input == "quit":
            with lock:
                running = False
                print("💾 Saving game data...")
                break
        else:
            print("❓ Invalid command. Type 'mine' or 'quit'.")

# -----------------------------
# SAVE FUNCTION
# -----------------------------
def save_gold_history():
    global gold_history
    filename = "gold_progress.csv"
    run_id = 1

    if os.path.exists(filename):
        existing = pd.read_csv(filename)

        while f"run_{run_id}_gold" in existing.columns:
            run_id += 1

        new_data = gold_history.copy()
        new_data.rename(columns={
            "gold": f"run_{run_id}_gold",
            "goldMine": f"run_{run_id}_goldMine"
        }, inplace=True)

        merged = pd.merge(existing, new_data, on="seconds", how="outer").sort_values(by="seconds")
    else:
        gold_history.rename(columns={
            "gold": f"run_1_gold",
            "goldMine": f"run_1_goldMine"
        }, inplace=True)
        merged = gold_history

    merged.to_csv(filename, index=False)
    print(f"✅ Game data saved as Run #{run_id} to {filename}")

# -----------------------------
# MAIN THREAD HANDLING
# -----------------------------
try:
    function_thread = threading.Thread(target=gold_function)
    input_thread = threading.Thread(target=get_user_input)

    function_thread.start()
    input_thread.start()

    function_thread.join()
    input_thread.join()
except KeyboardInterrupt:
    with lock:
        running = False
        print("\n🛑 Keyboard interrupt detected. Exiting gracefully...")

# -----------------------------
# FINAL SAVE ON EXIT
# -----------------------------
with lock:
    save_gold_history()
    print("🎮 Game ended.")
# Out:
# --- Game Status ---
# Time: 1 sec
# Gold: 135
# Multiplier: 5.50 (Handicap: +0.0)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2 sec
# Gold: 141
# Multiplier: 5.50 (Handicap: +0.0)
# Goldmines: 1
#
# --- Game Status ---
# Time: 3 sec
# Gold: 146
# Multiplier: 5.50 (Handicap: +0.0)
# Goldmines: 1
#
# --- Game Status ---
# Time: 4 sec
# Gold: 152
# Multiplier: 5.50 (Handicap: +0.0)
# Goldmines: 1
#
# --- Game Status ---
# Time: 5 sec
# Gold: 157
# Multiplier: 5.50 (Handicap: +0.0)
# Goldmines: 1
#
# --- Game Status ---
# Time: 6 sec
# Gold: 163
# Multiplier: 5.50 (Handicap: +0.0)
# Goldmines: 1
#
# --- Game Status ---
# Time: 7 sec
# Gold: 168
# Multiplier: 5.50 (Handicap: +0.0)
# Goldmines: 1
#
# --- Game Status ---
# Time: 8 sec
# Gold: 174
# Multiplier: 5.50 (Handicap: +0.0)
# Goldmines: 1
#
# --- Game Status ---
# Time: 9 sec
# Gold: 179
# Multiplier: 5.50 (Handicap: +0.0)
# Goldmines: 1
#
# --- Game Status ---
# Time: 10 sec
# Gold: 185
# Multiplier: 5.50 (Handicap: +0.0)
# Goldmines: 1
#
# --- Game Status ---
# Time: 11 sec
# Gold: 190
# Multiplier: 5.50 (Handicap: +0.0)
# Goldmines: 1
#
# --- Game Status ---
# Time: 12 sec
# Gold: 196
# Multiplier: 5.50 (Handicap: +0.0)
# Goldmines: 1
#
# --- Game Status ---
# Time: 13 sec
# Gold: 201
# Multiplier: 5.50 (Handicap: +0.0)
# Goldmines: 1
#
# --- Game Status ---
# Time: 14 sec
# Gold: 207
# Multiplier: 5.50 (Handicap: +0.0)
# Goldmines: 1
#
# --- Game Status ---
# Time: 15 sec
# Gold: 212
# Multiplier: 5.50 (Handicap: +0.0)
# Goldmines: 1
#
# --- Game Status ---
# Time: 16 sec
# Gold: 218
# Multiplier: 5.50 (Handicap: +0.0)
# Goldmines: 1
#
# --- Game Status ---
# Time: 17 sec
# Gold: 223
# Multiplier: 5.50 (Handicap: +0.0)
# Goldmines: 1
#
# --- Game Status ---
# Time: 18 sec
# Gold: 229
# Multiplier: 5.50 (Handicap: +0.0)
# Goldmines: 1
#
# --- Game Status ---
# Time: 19 sec
# Gold: 234
# Multiplier: 5.50 (Handicap: +0.0)
# Goldmines: 1
#
# --- Game Status ---
# Time: 20 sec
# Gold: 240
# Multiplier: 5.50 (Handicap: +0.0)
# Goldmines: 1
#
# --- Game Status ---
# Time: 21 sec
# Gold: 245
# Multiplier: 5.50 (Handicap: +0.0)
# Goldmines: 1
#
# --- Game Status ---
# Time: 22 sec
# Gold: 251
# Multiplier: 5.50 (Handicap: +0.0)
# Goldmines: 1
#
# --- Game Status ---
# Time: 23 sec
# Gold: 256
# Multiplier: 5.50 (Handicap: +0.0)
# Goldmines: 1
#
# --- Game Status ---
# Time: 24 sec
# Gold: 262
# Multiplier: 5.50 (Handicap: +0.0)
# Goldmines: 1
#
# --- Game Status ---
# Time: 25 sec
# Gold: 267
# Multiplier: 5.50 (Handicap: +0.0)
# Goldmines: 1
#
# --- Game Status ---
# Time: 26 sec
# Gold: 273
# Multiplier: 5.50 (Handicap: +0.0)
# Goldmines: 1
#
# --- Game Status ---
# Time: 27 sec
# Gold: 278
# Multiplier: 5.50 (Handicap: +0.0)
# Goldmines: 1
#
# --- Game Status ---
# Time: 28 sec
# Gold: 284
# Multiplier: 5.50 (Handicap: +0.0)
# Goldmines: 1
#
# --- Game Status ---
# Time: 29 sec
# Gold: 289
# Multiplier: 5.50 (Handicap: +0.0)
# Goldmines: 1
#
# --- Game Status ---
# Time: 30 sec
# Gold: 295
# Multiplier: 5.50 (Handicap: +0.0)
# Goldmines: 1
#
# --- Game Status ---
# Time: 31 sec
# Gold: 300
# Multiplier: 5.50 (Handicap: +0.0)
# Goldmines: 1
#
# --- Game Status ---
# Time: 32 sec
# Gold: 306
# Multiplier: 5.50 (Handicap: +0.0)
# Goldmines: 1
#
# --- Game Status ---
# Time: 33 sec
# Gold: 311
# Multiplier: 5.50 (Handicap: +0.0)
# Goldmines: 1
#
# --- Game Status ---
# Time: 34 sec
# Gold: 317
# Multiplier: 5.50 (Handicap: +0.0)
# Goldmines: 1
#
# --- Game Status ---
# Time: 35 sec
# Gold: 322
# Multiplier: 5.50 (Handicap: +0.0)
# Goldmines: 1
#
# --- Game Status ---
# Time: 36 sec
# Gold: 328
# Multiplier: 5.50 (Handicap: +0.0)
# Goldmines: 1
#
# --- Game Status ---
# Time: 37 sec
# Gold: 333
# Multiplier: 5.50 (Handicap: +0.0)
# Goldmines: 1
#
# --- Game Status ---
# Time: 38 sec
# Gold: 339
# Multiplier: 5.50 (Handicap: +0.0)
# Goldmines: 1
#
# --- Game Status ---
# Time: 39 sec
# Gold: 344
# Multiplier: 5.50 (Handicap: +0.0)
# Goldmines: 1
#
# --- Game Status ---
# Time: 40 sec
# Gold: 350
# Multiplier: 5.50 (Handicap: +0.0)
# Goldmines: 1
#
# --- Game Status ---
# Time: 41 sec
# Gold: 355
# Multiplier: 5.50 (Handicap: +0.0)
# Goldmines: 1
#
# --- Game Status ---
# Time: 42 sec
# Gold: 361
# Multiplier: 5.50 (Handicap: +0.0)
# Goldmines: 1
#
# --- Game Status ---
# Time: 43 sec
# Gold: 366
# Multiplier: 5.50 (Handicap: +0.0)
# Goldmines: 1
#
# --- Game Status ---
# Time: 44 sec
# Gold: 372
# Multiplier: 5.50 (Handicap: +0.0)
# Goldmines: 1
#
# --- Game Status ---
# Time: 45 sec
# Gold: 377
# Multiplier: 5.50 (Handicap: +0.0)
# Goldmines: 1
#
# --- Game Status ---
# Time: 46 sec
# Gold: 383
# Multiplier: 5.50 (Handicap: +0.0)
# Goldmines: 1
#
# --- Game Status ---
# Time: 47 sec
# Gold: 388
# Multiplier: 5.50 (Handicap: +0.0)
# Goldmines: 1
#
# --- Game Status ---
# Time: 48 sec
# Gold: 394
# Multiplier: 5.50 (Handicap: +0.0)
# Goldmines: 1
#
# --- Game Status ---
# Time: 49 sec
# Gold: 399
# Multiplier: 5.50 (Handicap: +0.0)
# Goldmines: 1
#
# --- Game Status ---
# Time: 50 sec
# Gold: 405
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 51 sec
# Gold: 411
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 52 sec
# Gold: 417
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 53 sec
# Gold: 423
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 54 sec
# Gold: 429
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 55 sec
# Gold: 435
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 56 sec
# Gold: 441
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 57 sec
# Gold: 447
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 58 sec
# Gold: 452
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 59 sec
# Gold: 458
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 60 sec
# Gold: 464
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 61 sec
# Gold: 470
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 62 sec
# Gold: 476
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 63 sec
# Gold: 482
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 64 sec
# Gold: 488
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 65 sec
# Gold: 494
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 66 sec
# Gold: 500
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 67 sec
# Gold: 506
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 68 sec
# Gold: 512
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 69 sec
# Gold: 517
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 70 sec
# Gold: 523
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 71 sec
# Gold: 529
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 72 sec
# Gold: 535
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 73 sec
# Gold: 541
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 74 sec
# Gold: 547
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 75 sec
# Gold: 553
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 76 sec
# Gold: 559
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 77 sec
# Gold: 565
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 78 sec
# Gold: 571
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 79 sec
# Gold: 576
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 80 sec
# Gold: 582
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 81 sec
# Gold: 588
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 82 sec
# Gold: 594
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 83 sec
# Gold: 600
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 84 sec
# Gold: 606
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 85 sec
# Gold: 612
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 86 sec
# Gold: 618
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 87 sec
# Gold: 624
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 88 sec
# Gold: 630
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 89 sec
# Gold: 636
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 90 sec
# Gold: 641
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 91 sec
# Gold: 647
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 92 sec
# Gold: 653
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 93 sec
# Gold: 659
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 94 sec
# Gold: 665
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 95 sec
# Gold: 671
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 96 sec
# Gold: 677
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 97 sec
# Gold: 683
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 98 sec
# Gold: 689
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 99 sec
# Gold: 695
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 100 sec
# Gold: 701
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 101 sec
# Gold: 706
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 102 sec
# Gold: 712
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 103 sec
# Gold: 718
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 104 sec
# Gold: 724
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 105 sec
# Gold: 730
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 106 sec
# Gold: 736
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 107 sec
# Gold: 742
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 108 sec
# Gold: 748
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 109 sec
# Gold: 754
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 110 sec
# Gold: 760
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 111 sec
# Gold: 765
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 112 sec
# Gold: 771
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 113 sec
# Gold: 777
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 114 sec
# Gold: 783
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 115 sec
# Gold: 789
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 116 sec
# Gold: 795
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 117 sec
# Gold: 801
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 118 sec
# Gold: 807
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 119 sec
# Gold: 813
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 120 sec
# Gold: 819
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 121 sec
# Gold: 825
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 122 sec
# Gold: 830
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 123 sec
# Gold: 836
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 124 sec
# Gold: 842
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 125 sec
# Gold: 848
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 126 sec
# Gold: 854
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 127 sec
# Gold: 860
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 128 sec
# Gold: 866
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 129 sec
# Gold: 872
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 130 sec
# Gold: 878
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 131 sec
# Gold: 884
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 132 sec
# Gold: 890
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 133 sec
# Gold: 895
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 134 sec
# Gold: 901
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 135 sec
# Gold: 907
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 136 sec
# Gold: 913
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 137 sec
# Gold: 919
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 138 sec
# Gold: 925
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 139 sec
# Gold: 931
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 140 sec
# Gold: 937
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 141 sec
# Gold: 943
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 142 sec
# Gold: 949
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 143 sec
# Gold: 954
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 144 sec
# Gold: 960
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 145 sec
# Gold: 966
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 146 sec
# Gold: 972
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 147 sec
# Gold: 978
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 148 sec
# Gold: 984
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 149 sec
# Gold: 990
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 150 sec
# Gold: 996
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 151 sec
# Gold: 1002
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 152 sec
# Gold: 1008
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 153 sec
# Gold: 1014
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 154 sec
# Gold: 1019
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 155 sec
# Gold: 1025
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 156 sec
# Gold: 1031
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 157 sec
# Gold: 1037
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 158 sec
# Gold: 1043
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 159 sec
# Gold: 1049
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 160 sec
# Gold: 1055
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 161 sec
# Gold: 1061
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 162 sec
# Gold: 1067
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 163 sec
# Gold: 1073
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 164 sec
# Gold: 1079
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 165 sec
# Gold: 1084
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 166 sec
# Gold: 1090
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 167 sec
# Gold: 1096
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 168 sec
# Gold: 1102
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 169 sec
# Gold: 1108
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 170 sec
# Gold: 1114
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 171 sec
# Gold: 1120
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 172 sec
# Gold: 1126
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 173 sec
# Gold: 1132
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 174 sec
# Gold: 1138
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 175 sec
# Gold: 1143
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 176 sec
# Gold: 1149
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 177 sec
# Gold: 1155
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 178 sec
# Gold: 1161
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 179 sec
# Gold: 1167
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 180 sec
# Gold: 1173
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 181 sec
# Gold: 1179
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 182 sec
# Gold: 1185
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 183 sec
# Gold: 1191
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 184 sec
# Gold: 1197
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 185 sec
# Gold: 1203
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 186 sec
# Gold: 1208
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 187 sec
# Gold: 1214
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 188 sec
# Gold: 1220
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 189 sec
# Gold: 1226
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 190 sec
# Gold: 1232
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 191 sec
# Gold: 1238
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 192 sec
# Gold: 1244
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 193 sec
# Gold: 1250
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 194 sec
# Gold: 1256
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 195 sec
# Gold: 1262
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 196 sec
# Gold: 1268
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 197 sec
# Gold: 1273
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 198 sec
# Gold: 1279
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 199 sec
# Gold: 1285
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 200 sec
# Gold: 1291
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 201 sec
# Gold: 1297
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 202 sec
# Gold: 1303
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 203 sec
# Gold: 1309
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 204 sec
# Gold: 1315
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 205 sec
# Gold: 1321
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 206 sec
# Gold: 1327
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 207 sec
# Gold: 1332
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 208 sec
# Gold: 1338
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 209 sec
# Gold: 1344
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 210 sec
# Gold: 1350
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 211 sec
# Gold: 1356
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 212 sec
# Gold: 1362
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 213 sec
# Gold: 1368
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 214 sec
# Gold: 1374
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 215 sec
# Gold: 1380
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 216 sec
# Gold: 1386
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 217 sec
# Gold: 1392
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 218 sec
# Gold: 1397
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 219 sec
# Gold: 1403
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 220 sec
# Gold: 1409
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 221 sec
# Gold: 1415
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 222 sec
# Gold: 1421
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 223 sec
# Gold: 1427
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 224 sec
# Gold: 1433
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 225 sec
# Gold: 1439
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 226 sec
# Gold: 1445
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 227 sec
# Gold: 1451
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 228 sec
# Gold: 1457
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 229 sec
# Gold: 1462
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 230 sec
# Gold: 1468
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 231 sec
# Gold: 1474
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 232 sec
# Gold: 1480
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 233 sec
# Gold: 1486
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 234 sec
# Gold: 1492
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 235 sec
# Gold: 1498
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 236 sec
# Gold: 1504
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 237 sec
# Gold: 1510
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 238 sec
# Gold: 1516
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 239 sec
# Gold: 1521
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 240 sec
# Gold: 1527
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 241 sec
# Gold: 1533
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 242 sec
# Gold: 1539
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 243 sec
# Gold: 1545
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 244 sec
# Gold: 1551
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 245 sec
# Gold: 1557
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 246 sec
# Gold: 1563
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 247 sec
# Gold: 1569
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 248 sec
# Gold: 1575
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 249 sec
# Gold: 1581
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 250 sec
# Gold: 1586
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 251 sec
# Gold: 1592
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 252 sec
# Gold: 1598
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 253 sec
# Gold: 1604
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 254 sec
# Gold: 1610
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 255 sec
# Gold: 1616
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 256 sec
# Gold: 1622
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 257 sec
# Gold: 1628
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 258 sec
# Gold: 1634
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 259 sec
# Gold: 1640
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 260 sec
# Gold: 1645
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 261 sec
# Gold: 1651
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 262 sec
# Gold: 1657
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 263 sec
# Gold: 1663
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 264 sec
# Gold: 1669
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 265 sec
# Gold: 1675
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 266 sec
# Gold: 1681
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 267 sec
# Gold: 1687
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 268 sec
# Gold: 1693
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 269 sec
# Gold: 1699
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 270 sec
# Gold: 1705
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 271 sec
# Gold: 1710
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 272 sec
# Gold: 1716
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 273 sec
# Gold: 1722
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 274 sec
# Gold: 1728
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 275 sec
# Gold: 1734
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 276 sec
# Gold: 1740
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 277 sec
# Gold: 1746
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 278 sec
# Gold: 1752
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 279 sec
# Gold: 1758
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 280 sec
# Gold: 1764
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 281 sec
# Gold: 1770
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 282 sec
# Gold: 1775
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 283 sec
# Gold: 1781
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 284 sec
# Gold: 1787
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 285 sec
# Gold: 1793
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 286 sec
# Gold: 1799
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 287 sec
# Gold: 1805
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 288 sec
# Gold: 1811
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 289 sec
# Gold: 1817
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 290 sec
# Gold: 1823
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 291 sec
# Gold: 1829
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 292 sec
# Gold: 1834
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 293 sec
# Gold: 1840
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 294 sec
# Gold: 1846
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 295 sec
# Gold: 1852
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 296 sec
# Gold: 1858
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 297 sec
# Gold: 1864
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 298 sec
# Gold: 1870
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 299 sec
# Gold: 1876
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 300 sec
# Gold: 1882
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 301 sec
# Gold: 1888
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 302 sec
# Gold: 1894
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 303 sec
# Gold: 1899
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 304 sec
# Gold: 1905
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 305 sec
# Gold: 1911
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 306 sec
# Gold: 1917
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 307 sec
# Gold: 1923
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 308 sec
# Gold: 1929
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 309 sec
# Gold: 1935
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 310 sec
# Gold: 1941
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 311 sec
# Gold: 1947
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 312 sec
# Gold: 1953
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 313 sec
# Gold: 1959
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 314 sec
# Gold: 1964
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 315 sec
# Gold: 1970
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 316 sec
# Gold: 1976
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 317 sec
# Gold: 1982
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 318 sec
# Gold: 1988
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 319 sec
# Gold: 1994
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 320 sec
# Gold: 2000
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 321 sec
# Gold: 2006
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 322 sec
# Gold: 2012
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 323 sec
# Gold: 2018
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 324 sec
# Gold: 2023
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 325 sec
# Gold: 2029
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 326 sec
# Gold: 2035
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 327 sec
# Gold: 2041
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 328 sec
# Gold: 2047
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 329 sec
# Gold: 2053
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 330 sec
# Gold: 2059
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 331 sec
# Gold: 2065
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 332 sec
# Gold: 2071
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 333 sec
# Gold: 2077
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 334 sec
# Gold: 2083
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 335 sec
# Gold: 2088
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 336 sec
# Gold: 2094
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 337 sec
# Gold: 2100
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 338 sec
# Gold: 2106
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 339 sec
# Gold: 2112
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 340 sec
# Gold: 2118
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 341 sec
# Gold: 2124
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 342 sec
# Gold: 2130
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 343 sec
# Gold: 2136
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 344 sec
# Gold: 2142
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 345 sec
# Gold: 2148
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 346 sec
# Gold: 2153
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 347 sec
# Gold: 2159
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 348 sec
# Gold: 2165
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 349 sec
# Gold: 2171
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 350 sec
# Gold: 2177
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 351 sec
# Gold: 2183
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 352 sec
# Gold: 2189
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 353 sec
# Gold: 2195
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 354 sec
# Gold: 2201
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 355 sec
# Gold: 2207
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 356 sec
# Gold: 2212
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 357 sec
# Gold: 2218
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 358 sec
# Gold: 2224
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 359 sec
# Gold: 2230
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 360 sec
# Gold: 2236
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 361 sec
# Gold: 2242
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 362 sec
# Gold: 2248
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 363 sec
# Gold: 2254
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 364 sec
# Gold: 2260
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 365 sec
# Gold: 2266
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 366 sec
# Gold: 2272
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 367 sec
# Gold: 2277
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 368 sec
# Gold: 2283
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 369 sec
# Gold: 2289
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 370 sec
# Gold: 2295
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 371 sec
# Gold: 2301
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 372 sec
# Gold: 2307
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 373 sec
# Gold: 2313
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 374 sec
# Gold: 2319
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 375 sec
# Gold: 2325
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 376 sec
# Gold: 2331
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 377 sec
# Gold: 2337
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 378 sec
# Gold: 2342
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 379 sec
# Gold: 2348
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 380 sec
# Gold: 2354
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 381 sec
# Gold: 2360
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 382 sec
# Gold: 2366
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 383 sec
# Gold: 2372
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 384 sec
# Gold: 2378
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 385 sec
# Gold: 2384
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 386 sec
# Gold: 2390
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 387 sec
# Gold: 2396
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 388 sec
# Gold: 2401
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 389 sec
# Gold: 2407
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 390 sec
# Gold: 2413
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 391 sec
# Gold: 2419
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 392 sec
# Gold: 2425
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 393 sec
# Gold: 2431
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 394 sec
# Gold: 2437
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 395 sec
# Gold: 2443
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 396 sec
# Gold: 2449
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 397 sec
# Gold: 2455
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 398 sec
# Gold: 2461
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 399 sec
# Gold: 2466
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 400 sec
# Gold: 2472
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 401 sec
# Gold: 2478
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 402 sec
# Gold: 2484
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 403 sec
# Gold: 2490
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 404 sec
# Gold: 2496
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 405 sec
# Gold: 2502
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 406 sec
# Gold: 2508
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 407 sec
# Gold: 2514
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 408 sec
# Gold: 2520
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 409 sec
# Gold: 2525
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 410 sec
# Gold: 2531
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 411 sec
# Gold: 2537
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 412 sec
# Gold: 2543
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 413 sec
# Gold: 2549
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 414 sec
# Gold: 2555
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 415 sec
# Gold: 2561
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 416 sec
# Gold: 2567
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 417 sec
# Gold: 2573
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 418 sec
# Gold: 2579
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 419 sec
# Gold: 2585
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 420 sec
# Gold: 2590
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 421 sec
# Gold: 2596
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 422 sec
# Gold: 2602
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 423 sec
# Gold: 2608
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 424 sec
# Gold: 2614
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 425 sec
# Gold: 2620
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 426 sec
# Gold: 2626
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 427 sec
# Gold: 2632
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 428 sec
# Gold: 2638
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 429 sec
# Gold: 2644
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 430 sec
# Gold: 2650
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 431 sec
# Gold: 2655
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 432 sec
# Gold: 2661
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 433 sec
# Gold: 2667
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 434 sec
# Gold: 2673
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 435 sec
# Gold: 2679
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 436 sec
# Gold: 2685
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 437 sec
# Gold: 2691
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 438 sec
# Gold: 2697
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 439 sec
# Gold: 2703
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 440 sec
# Gold: 2709
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 441 sec
# Gold: 2714
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 442 sec
# Gold: 2720
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 443 sec
# Gold: 2726
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 444 sec
# Gold: 2732
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 445 sec
# Gold: 2738
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 446 sec
# Gold: 2744
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 447 sec
# Gold: 2750
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 448 sec
# Gold: 2756
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 449 sec
# Gold: 2762
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 450 sec
# Gold: 2768
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 451 sec
# Gold: 2774
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 452 sec
# Gold: 2779
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 453 sec
# Gold: 2785
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 454 sec
# Gold: 2791
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 455 sec
# Gold: 2797
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 456 sec
# Gold: 2803
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 457 sec
# Gold: 2809
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 458 sec
# Gold: 2815
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 459 sec
# Gold: 2821
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 460 sec
# Gold: 2827
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 461 sec
# Gold: 2833
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 462 sec
# Gold: 2839
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 463 sec
# Gold: 2844
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 464 sec
# Gold: 2850
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 465 sec
# Gold: 2856
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 466 sec
# Gold: 2862
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 467 sec
# Gold: 2868
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 468 sec
# Gold: 2874
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 469 sec
# Gold: 2880
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 470 sec
# Gold: 2886
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 471 sec
# Gold: 2892
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 472 sec
# Gold: 2898
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 473 sec
# Gold: 2903
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 474 sec
# Gold: 2909
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 475 sec
# Gold: 2915
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 476 sec
# Gold: 2921
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 477 sec
# Gold: 2927
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 478 sec
# Gold: 2933
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 479 sec
# Gold: 2939
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 480 sec
# Gold: 2945
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 481 sec
# Gold: 2951
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 482 sec
# Gold: 2957
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 483 sec
# Gold: 2963
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 484 sec
# Gold: 2968
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 485 sec
# Gold: 2974
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 486 sec
# Gold: 2980
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 487 sec
# Gold: 2986
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 488 sec
# Gold: 2992
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 489 sec
# Gold: 2998
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 490 sec
# Gold: 3004
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 491 sec
# Gold: 3010
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 492 sec
# Gold: 3016
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 493 sec
# Gold: 3022
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 494 sec
# Gold: 3028
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 495 sec
# Gold: 3033
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 496 sec
# Gold: 3039
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 497 sec
# Gold: 3045
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 498 sec
# Gold: 3051
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 499 sec
# Gold: 3057
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 500 sec
# Gold: 3063
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 501 sec
# Gold: 3069
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 502 sec
# Gold: 3075
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 503 sec
# Gold: 3081
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 504 sec
# Gold: 3087
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 505 sec
# Gold: 3093
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 506 sec
# Gold: 3098
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 507 sec
# Gold: 3104
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 508 sec
# Gold: 3110
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 509 sec
# Gold: 3116
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 510 sec
# Gold: 3122
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 511 sec
# Gold: 3128
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 512 sec
# Gold: 3134
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 513 sec
# Gold: 3140
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 514 sec
# Gold: 3146
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 515 sec
# Gold: 3152
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 516 sec
# Gold: 3157
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 517 sec
# Gold: 3163
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 518 sec
# Gold: 3169
# Multiplier: 5.90 (Handicap: +0.4)
# Goldmines: 1
#
# --- Game Status ---
# Time: 519 sec
# Gold: 3175
# Multiplier: 5.90 (Handicap: +0.4)
# ...
# Goldmines: 1
#
# --- Game Status ---
# Time: 1934 sec
# Gold: 11272
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 1935 sec
# Gold: 11277
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 1936 sec
# Gold: 11283
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 1937 sec
# Gold: 11289
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 1938 sec
# Gold: 11294
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 1939 sec
# Gold: 11300
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 1940 sec
# Gold: 11306
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 1941 sec
# Gold: 11311
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 1942 sec
# Gold: 11317
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 1943 sec
# Gold: 11323
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 1944 sec
# Gold: 11329
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 1945 sec
# Gold: 11334
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 1946 sec
# Gold: 11340
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 1947 sec
# Gold: 11346
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 1948 sec
# Gold: 11351
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 1949 sec
# Gold: 11357
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 1950 sec
# Gold: 11363
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 1951 sec
# Gold: 11369
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 1952 sec
# Gold: 11374
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 1953 sec
# Gold: 11380
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 1954 sec
# Gold: 11386
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 1955 sec
# Gold: 11391
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 1956 sec
# Gold: 11397
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 1957 sec
# Gold: 11403
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 1958 sec
# Gold: 11408
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 1959 sec
# Gold: 11414
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 1960 sec
# Gold: 11420
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 1961 sec
# Gold: 11426
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 1962 sec
# Gold: 11431
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 1963 sec
# Gold: 11437
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 1964 sec
# Gold: 11443
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 1965 sec
# Gold: 11448
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 1966 sec
# Gold: 11454
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 1967 sec
# Gold: 11460
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 1968 sec
# Gold: 11466
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 1969 sec
# Gold: 11471
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 1970 sec
# Gold: 11477
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 1971 sec
# Gold: 11483
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 1972 sec
# Gold: 11488
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 1973 sec
# Gold: 11494
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 1974 sec
# Gold: 11500
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 1975 sec
# Gold: 11505
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 1976 sec
# Gold: 11511
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 1977 sec
# Gold: 11517
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 1978 sec
# Gold: 11523
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 1979 sec
# Gold: 11528
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 1980 sec
# Gold: 11534
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 1981 sec
# Gold: 11540
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 1982 sec
# Gold: 11545
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 1983 sec
# Gold: 11551
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 1984 sec
# Gold: 11557
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 1985 sec
# Gold: 11563
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 1986 sec
# Gold: 11568
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 1987 sec
# Gold: 11574
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 1988 sec
# Gold: 11580
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 1989 sec
# Gold: 11585
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 1990 sec
# Gold: 11591
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 1991 sec
# Gold: 11597
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 1992 sec
# Gold: 11602
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 1993 sec
# Gold: 11608
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 1994 sec
# Gold: 11614
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 1995 sec
# Gold: 11620
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 1996 sec
# Gold: 11625
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 1997 sec
# Gold: 11631
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 1998 sec
# Gold: 11637
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 1999 sec
# Gold: 11642
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2000 sec
# Gold: 11648
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2001 sec
# Gold: 11654
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2002 sec
# Gold: 11660
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2003 sec
# Gold: 11665
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2004 sec
# Gold: 11671
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2005 sec
# Gold: 11677
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2006 sec
# Gold: 11682
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2007 sec
# Gold: 11688
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2008 sec
# Gold: 11694
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2009 sec
# Gold: 11699
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2010 sec
# Gold: 11705
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2011 sec
# Gold: 11711
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2012 sec
# Gold: 11717
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2013 sec
# Gold: 11722
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2014 sec
# Gold: 11728
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2015 sec
# Gold: 11734
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2016 sec
# Gold: 11739
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2017 sec
# Gold: 11745
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2018 sec
# Gold: 11751
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2019 sec
# Gold: 11757
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2020 sec
# Gold: 11762
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2021 sec
# Gold: 11768
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2022 sec
# Gold: 11774
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2023 sec
# Gold: 11779
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2024 sec
# Gold: 11785
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2025 sec
# Gold: 11791
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2026 sec
# Gold: 11796
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2027 sec
# Gold: 11802
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2028 sec
# Gold: 11808
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2029 sec
# Gold: 11814
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2030 sec
# Gold: 11819
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2031 sec
# Gold: 11825
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2032 sec
# Gold: 11831
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2033 sec
# Gold: 11836
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2034 sec
# Gold: 11842
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2035 sec
# Gold: 11848
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2036 sec
# Gold: 11854
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2037 sec
# Gold: 11859
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2038 sec
# Gold: 11865
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2039 sec
# Gold: 11871
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2040 sec
# Gold: 11876
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2041 sec
# Gold: 11882
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2042 sec
# Gold: 11888
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2043 sec
# Gold: 11893
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2044 sec
# Gold: 11899
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2045 sec
# Gold: 11905
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2046 sec
# Gold: 11911
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2047 sec
# Gold: 11916
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2048 sec
# Gold: 11922
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2049 sec
# Gold: 11928
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2050 sec
# Gold: 11933
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2051 sec
# Gold: 11939
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2052 sec
# Gold: 11945
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2053 sec
# Gold: 11951
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2054 sec
# Gold: 11956
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2055 sec
# Gold: 11962
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2056 sec
# Gold: 11968
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2057 sec
# Gold: 11973
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2058 sec
# Gold: 11979
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2059 sec
# Gold: 11985
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2060 sec
# Gold: 11990
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2061 sec
# Gold: 11996
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2062 sec
# Gold: 12002
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2063 sec
# Gold: 12008
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2064 sec
# Gold: 12013
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2065 sec
# Gold: 12019
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2066 sec
# Gold: 12025
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2067 sec
# Gold: 12030
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2068 sec
# Gold: 12036
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2069 sec
# Gold: 12042
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2070 sec
# Gold: 12048
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2071 sec
# Gold: 12053
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2072 sec
# Gold: 12059
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2073 sec
# Gold: 12065
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2074 sec
# Gold: 12070
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2075 sec
# Gold: 12076
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2076 sec
# Gold: 12082
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2077 sec
# Gold: 12087
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2078 sec
# Gold: 12093
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2079 sec
# Gold: 12099
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2080 sec
# Gold: 12105
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2081 sec
# Gold: 12110
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2082 sec
# Gold: 12116
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2083 sec
# Gold: 12122
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2084 sec
# Gold: 12127
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2085 sec
# Gold: 12133
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2086 sec
# Gold: 12139
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2087 sec
# Gold: 12145
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2088 sec
# Gold: 12150
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2089 sec
# Gold: 12156
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2090 sec
# Gold: 12162
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2091 sec
# Gold: 12167
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2092 sec
# Gold: 12173
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2093 sec
# Gold: 12179
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2094 sec
# Gold: 12184
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2095 sec
# Gold: 12190
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2096 sec
# Gold: 12196
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2097 sec
# Gold: 12202
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2098 sec
# Gold: 12207
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# --- Game Status ---
# Time: 2099 sec
# Gold: 12213
# Multiplier: 5.70 (Handicap: +0.2)
# Goldmines: 1
#
# ⏰ 35 minutes have passed. Ending game.
# Enter 'mine' to build a Goldmine (90 sec cooldown), or 'quit' to exit:  quit
# 💾 Saving game data...
# ✅ Game data saved as Run #8 to gold_progress.csv
# 🎮 Game ended.
